# %%
from pprint import pprint
import pandas as pd
import json

# %%
def load_json_from_file(filename):
    """Load JSON data from file and return as Python dict"""
    
    with open(filename) as f:
        data = json.load(f)
    
    return data

# %%
def dict_to_df(dictionary):
    return pd.DataFrame(dictionary)

# %%
def file_name_to_df(filename):
    return dict_to_df(load_json_from_file(filename)['response']['docs'])

# %%
df = file_name_to_df('data/FruitsVegetables.json')
df
# Out:
#      status                                               name        pid  \
# 0    active                                      Banana - Each  184060007
# 1    active  Follow Your Heart Dairy-Free Finely Shredded M...  970094157
# 2    active                                Medium Hass Avocado  184040105
# 3    active  Follow Your Heart Dairy-Free Finely Shredded C...  970094168
# 4    active                                   Honeycrisp Apple  184020020
# ..      ...                                                ...        ...
# 119  active     O Organics California Mandarins In Bag - 2 Lbs  970480596
# 120  active     Fresh Cut Jalapenos Stuffed With Bacon - 10 Oz  960131448
# 121  active                                     Organic Banana  184700054
# 122  active                                 Cilantro - 1 Bunch  184410069
# 123  active  Plated Squash Baking Tray With Garlic Butter -...  970014823
#
#                upc         id  featured inventoryAvailable  pastPurchased  \
# 0    0048406000701  184060007     False                  1          False
# 1    0004956816007  970094157      True                  1          False
# 2    0048404010501  184040105     False                  1          False
# 3    0004956815007  970094168      True                  1          False
# 4    0048402002001  184020020     False                  1          False
# ..             ...        ...       ...                ...            ...
# 119  0007989316045  970480596     False                  1          False
# 120  0024206400000  960131448     False                  1          False
# 121  0048470005401  184700054     False                  1          False
# 122  0048441002701  184410069     False                  1          False
# 123  0003828110213  970014823     False                  1          False
#
#     restrictedValue  salesRank  ...  \
# 0                 0          1  ...
# 1                 0      99999  ...
# 2                 0          3  ...
# 3                 0      99999  ...
# 4                 0          4  ...
# ..              ...        ...  ...
# 119               0      99999  ...
# 120               0       6708  ...
# 121               0          5  ...
# 122               0         26  ...
# 123               0      99999  ...
#
#                                   promoDescription  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4    Club Card Price: $1.99 Lb Save Up To: $2.0 Lb
# ..                                             ...
# 119        Club Card Price: $4.99 Save Up To: $1.0
# 120                                            NaN
# 121                                            NaN
# 122                                            NaN
# 123                                            NaN
#
#                          promoText promoType  shelfXcoordinateNbr  \
# 0                              NaN       NaN                  NaN
# 1                              NaN       NaN                  NaN
# 2                              NaN       NaN                  NaN
# 3                              NaN       NaN                  NaN
# 4     $1.99 Lb Save Up To: $2.0 Lb         P                  NaN
# ..                             ...       ...                  ...
# 119         $4.99 Save Up To: $1.0         P                  NaN
# 120                            NaN       NaN                  NaN
# 121                            NaN       NaN                  NaN
# 122                            NaN       NaN                  NaN
# 123                            NaN       NaN                  NaN
#
#     shelfYcoordinateNbr  slotXcoordinateNbr  slotYcoordinateNbr  \
# 0                   NaN                 NaN                 NaN
# 1                   NaN                 NaN                 NaN
# 2                   NaN                 NaN                 NaN
# 3                   NaN                 NaN                 NaN
# 4                   NaN                 NaN                 NaN
# ..                  ...                 ...                 ...
# 119                 NaN                 NaN                 NaN
# 120                 NaN                 NaN                 NaN
# 121                 NaN                 NaN                 NaN
# 122                 NaN                 NaN                 NaN
# 123                 NaN                 NaN                 NaN
#
#     fixtureXcoordinateNbr fixtureYcoordinateNbr aislePositionTxt
# 0                     NaN                   NaN              NaN
# 1                     NaN                   NaN              NaN
# 2                     NaN                   NaN              NaN
# 3                     NaN                   NaN              NaN
# 4                     NaN                   NaN              NaN
# ..                    ...                   ...              ...
# 119                   NaN                   NaN              NaN
# 120                   NaN                   NaN              NaN
# 121                   NaN                   NaN              NaN
# 122                   NaN                   NaN              NaN
# 123                   NaN                   NaN              NaN
#
# [124 rows x 66 columns]
